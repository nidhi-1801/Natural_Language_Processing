# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi-1801/Natural_Language_Processing/blob/main/Name_Entity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NER** is the process of identifying and classifying real-world entities in text — such as names of people, organizations, places, dates, or events.

# %%
Sentence = "Dr. A.P.J. Abdul Kalam worked on India’s space program."

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(Sentence)
print(tokens)
# Out:
# ['Dr.', 'A.P.J', '.', 'Abdul', 'Kalam', 'worked', 'on', 'India', '’', 's', 'space', 'program', '.']

# %%
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Dr.', 'NNP'), ('A.P.J', 'NNP'), ('.', '.'), ('Abdul', 'NNP'), ('Kalam', 'NNP'), ('worked', 'VBD'), ('on', 'IN'), ('India', 'NNP'), ('’', 'NNP'), ('s', 'JJ'), ('space', 'NN'), ('program', 'NN'), ('.', '.')]

# %%
nltk.ne_chunk(pos_tags)
# Out:
# Tree('S', [('Dr.', 'NNP'), ('A.P.J', 'NNP'), ('.', '.'), Tree('PERSON', [('Abdul', 'NNP'), ('Kalam', 'NNP')]), ('worked', 'VBD'), ('on', 'IN'), Tree('GPE', [('India', 'NNP')]), ('’', 'NNP'), ('s', 'JJ'), ('space', 'NN'), ('program', 'NN'), ('.', '.')])

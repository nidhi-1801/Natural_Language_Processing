# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi-1801/Natural_Language_Processing/blob/main/Text_Preprocessing_Stopwords_with_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Speech of DR APJ Abdul Kalam
Paragraph = ''' Dream, dream, dream.
Dreams transform into thoughts.
Thoughts result in action.

You have to dream before your dreams can come true.

When I was a young boy, I had a dream to fly.
That dream led me to study aeronautical engineering.
It led me to work on India's space programs.
It finally led me to become the President of India.

Each one of you has hidden potential.
Success comes to those who work hard and stay confident.

You must have a clear goal in life.
Obstacles will appear, but they test your determination.

If you fail, never give up.
FAIL means "First Attempt In Learning".
END is not the end; it means "Effort Never Dies".
If you get NO as an answer, remember it means "Next Opportunity".

Dream big, think big, and work hard.
That is the way to achieve success. '''

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#To see stopwords that are available in english, you can check for any language.
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
#step2 tokenize
from nltk.tokenize import word_tokenize
tokens = word_tokenize(Paragraph)
print(word)
# Out:
# ['Dream', ',', 'dream', ',', 'dream', '.', 'Dreams', 'transform', 'into', 'thoughts', '.', 'Thoughts', 'result', 'in', 'action', '.', 'You', 'have', 'to', 'dream', 'before', 'your', 'dreams', 'can', 'come', 'true', '.', 'When', 'I', 'was', 'a', 'young', 'boy', ',', 'I', 'had', 'a', 'dream', 'to', 'fly', '.', 'That', 'dream', 'led', 'me', 'to', 'study', 'aeronautical', 'engineering', '.', 'It', 'led', 'me', 'to', 'work', 'on', 'India', "'s", 'space', 'programs', '.', 'It', 'finally', 'led', 'me', 'to', 'become', 'the', 'President', 'of', 'India', '.', 'Each', 'one', 'of', 'you', 'has', 'hidden', 'potential', '.', 'Success', 'comes', 'to', 'those', 'who', 'work', 'hard', 'and', 'stay', 'confident', '.', 'You', 'must', 'have', 'a', 'clear', 'goal', 'in', 'life', '.', 'Obstacles', 'will', 'appear', ',', 'but', 'they', 'test', 'your', 'determination', '.', 'If', 'you', 'fail', ',', 'never', 'give', 'up', '.', 'FAIL', 'means', '``', 'First', 'Attempt', 'In', 'Learning', "''", '.', 'END', '
# ...

# %%
#step3
#Load stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
#step4
#remove stopwords
#We filter out all stopwords and keep meaningful words.
filtered_tokens = [word for word in tokens if word not in stop_words]
print(filtered_tokens)
# Out:
# ['Dream', ',', 'dream', ',', 'dream', '.', 'Dreams', 'transform', 'thoughts', '.', 'Thoughts', 'result', 'action', '.', 'You', 'dream', 'dreams', 'come', 'true', '.', 'When', 'I', 'young', 'boy', ',', 'I', 'dream', 'fly', '.', 'That', 'dream', 'led', 'study', 'aeronautical', 'engineering', '.', 'It', 'led', 'work', 'India', "'s", 'space', 'programs', '.', 'It', 'finally', 'led', 'become', 'President', 'India', '.', 'Each', 'one', 'hidden', 'potential', '.', 'Success', 'comes', 'work', 'hard', 'stay', 'confident', '.', 'You', 'must', 'clear', 'goal', 'life', '.', 'Obstacles', 'appear', ',', 'test', 'determination', '.', 'If', 'fail', ',', 'never', 'give', '.', 'FAIL', 'means', '``', 'First', 'Attempt', 'In', 'Learning', "''", '.', 'END', 'end', ';', 'means', '``', 'Effort', 'Never', 'Dies', "''", '.', 'If', 'get', 'NO', 'answer', ',', 'remember', 'means', '``', 'Next', 'Opportunity', "''", '.', 'Dream', 'big', ',', 'think', 'big', ',', 'work', 'hard', '.', 'That', 'way', 'achieve', 's
# ...

# %%
#step5
#rejoin tokens
cleaned_text = " ".join(filtered_tokens)
print(cleaned_text)
# Out:
# Dream , dream , dream . Dreams transform thoughts . Thoughts result action . You dream dreams come true . When I young boy , I dream fly . That dream led study aeronautical engineering . It led work India 's space programs . It finally led become President India . Each one hidden potential . Success comes work hard stay confident . You must clear goal life . Obstacles appear , test determination . If fail , never give . FAIL means `` First Attempt In Learning '' . END end ; means `` Effort Never Dies '' . If get NO answer , remember means `` Next Opportunity '' . Dream big , think big , work hard . That way achieve success .

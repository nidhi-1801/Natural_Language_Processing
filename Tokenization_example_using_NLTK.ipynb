# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhi-1801/Natural_Language_Processing/blob/main/Tokenization_example_using_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus=""" Hello welcome, to Nidhi's notebook.
           Please go through the notebook, to understand more about NLP."""

# %%
print(corpus)
# Out:
#  Hello welcome, to Nidhi's notebook.
#            Please go through the notebook, to understand more about NLP.

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Nidhi',
#  "'s",
#  'notebook',
#  '.',
#  'Please',
#  'go',
#  'through',
#  'the',
#  'notebook',
#  ',',
#  'to',
#  'understand',
#  'more',
#  'about',
#  'NLP',
#  '.']

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'Nidhi', "'s", 'notebook', '.']
# ['Please', 'go', 'through', 'the', 'notebook', ',', 'to', 'understand', 'more', 'about', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Nidhi',
#  "'",
#  's',
#  'notebook',
#  '.',
#  'Please',
#  'go',
#  'through',
#  'the',
#  'notebook',
#  ',',
#  'to',
#  'understand',
#  'more',
#  'about',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokenizer=TreebankWordDetokenizer()    #treebankwordtokenized doesn't take any arguments
tokenizer.tokenize(corpus)
